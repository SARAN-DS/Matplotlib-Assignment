# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s=np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
temp_min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])
months=np.arange(12)

# %%
plt.plot(months,s,'go')
plt.plot(months,temp_min,'co')
plt.xlabel('month')
plt.ylabel('temp_min')
# Out:
# Text(0, 0.5, 'temp_min')

# %%
d=pd.read_csv("https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv")

# %%
df=(d['sex'].value_counts())

# %%
df
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='sex'>], dtype=object)

# %%
plt.figure()
count1=d[d.sex=='male'].plot.scatter(x='fare',y='age',label='male')
d[d.sex=='female'].plot.scatter(x='fare',y='age',label='female',color='yellow',ax=count1)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='age'>
